# %%
# Sequence-to-Sequence Learning with LSTM

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import random
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from collections import Counter
from torch.nn.utils.rnn import pad_sequence
from nltk.translate.bleu_score import corpus_bleu, SmoothingFunction

# %%
# Check If CUDA is Available, Else use CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
modes = ["without_attention", "bahdanau", "luong"]

# %%
# Load Dataset
def load_data(path, limit = 10000):
    with open(path, "r", encoding = 'utf-8') as f:
        lines = [line.strip().split('\t') for line in f if '\t' in line]
    random.shuffle(lines)
    
    return lines[:limit]

# %%
# Build Vocabulary
def build_vocab(sentences):
    vocab = {'<pad>': 0, '<sos>': 1, '<eos>': 2, '<unk>': 3}
    counter = Counter(word for s in sentences for word in s.lower().split())
    for word in counter:
        vocab[word] = len(vocab)
        
    return vocab

# %%
# Tokenize Sentence
def tokenize(sentence, vocab):
    return [vocab.get(w, vocab['<unk>']) for w in sentence.lower().split()]

# %%
# Prepare Dataset
def prepare_dataset(pairs, src_vocab, tgt_vocab):
    X, Y = [], []
    for src, tgt in pairs:
        x = tokenize(src, src_vocab)
        y = [tgt_vocab['<sos>']] + tokenize(tgt, tgt_vocab) + [tgt_vocab['<eos>']]
        X.append(torch.tensor(x, dtype = torch.long))
        Y.append(torch.tensor(y, dtype = torch.long))
        
    return X, Y

# %%
# Pad Batch
def collate_fn(batch_x, batch_y):
    src = pad_sequence(batch_x, batch_first = True, padding_value = src_vocab['<pad>'])
    tgt = pad_sequence(batch_y, batch_first = True, padding_value = tgt_vocab['<pad>'])
    return src.to(device), tgt.to(device)

# %%
# Encoder
class Encoder(nn.Module):
    def __init__(self, vocab_size, embed_size, hidden_size):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embed_size)
        self.lstm = nn.LSTM(embed_size, hidden_size, batch_first = True)
        
    def forward(self, x):
        x = self.embedding(x)
        outputs, (h, c) = self.lstm(x)
        
        return outputs, (h, c)

# %%
# Bahdanau Attention
class BahdanauAttention(nn.Module):
    def __init__(self, hidden_size):
        super().__init__()
        self.attn = nn.Linear(hidden_size * 2, hidden_size)
        self.v = nn.Parameter(torch.rand(hidden_size))
        
    def forward(self, hidden, encoder_outputs):
        hidden = hidden[-1].unsqueeze(1).repeat(1, encoder_outputs.size(1), 1)
        energy = torch.tanh(self.attn(torch.cat((hidden, encoder_outputs), dim = 2)))
        score = torch.sum(self.v * energy, dim = 2)
        
        return torch.softmax(score, dim = 1)

# %%
# Luong Attention
class LuongAttention(nn.Module):
    def __init__(self, hidden_size):
        super().__init__()
        self.attn = nn.Linear(hidden_size, hidden_size)
        
    def forward(self, hidden, encoder_outputs):
        hidden = hidden[-1].unsqueeze(2)
        energy = self.attn(encoder_outputs)
        score = torch.bmm(energy, hidden).squeeze(2)
        
        return torch.softmax(score, dim = 1)

# %%
# Decoder
class Decoder(nn.Module):
    def __init__(self, vocab_size, embed_size, hidden_size, mode):
        super().__init__()
        self.mode = mode
        self.embedding = nn.Embedding(vocab_size, embed_size)
        self.attn = BahdanauAttention(hidden_size) if mode == "bahdanau" else \
                    LuongAttention(hidden_size) if mode == "luong" else None
        self.lstm = nn.LSTM(embed_size + hidden_size if self.attn else embed_size, hidden_size, batch_first = True)
        self.fc = nn.Linear(hidden_size * 2 if self.attn else hidden_size, vocab_size)
        
    def forward(self, x, hidden, cell, encoder_outputs = None):
        x = self.embedding(x.unsqueeze(1))
        attn_weights = None
        if self.attn:
            attn_weights = self.attn(hidden, encoder_outputs)
            context = torch.bmm(attn_weights.unsqueeze(1), encoder_outputs)
            x = torch.cat((x, context), dim = 2)
        output, (hidden, cell) = self.lstm(x, (hidden, cell))
        if self.attn:
            output = torch.cat((output.squeeze(1), context.squeeze(1)), dim = 1)
        else:
            output = output.squeeze(1)
            
        return self.fc(output), hidden, cell, attn_weights

# %%
# Seq2Seq Model
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder):
        super().__init__()
        self.encoder = encoder
        self.decoder = decoder
        
    def forward(self, src, tgt, teacher_forcing = 0.5):
        batch_size, tgt_len = tgt.shape
        vocab_size = self.decoder.fc.out_features
        outputs = torch.zeros(batch_size, tgt_len, vocab_size).to(device)
        enc_outputs, (h, c) = self.encoder(src)
        x = tgt[:, 0]
        for t in range(1, tgt_len):
            out, h, c, _ = self.decoder(x, h, c, enc_outputs if self.decoder.attn else None)
            outputs[:, t] = out
            x = tgt[:, t] if random.random() < teacher_forcing else out.argmax(1)
            
        return outputs

# %%
# Training the Model
# Training the Model
def train(model, xdata, ydata, val_data = None, epochs = 5):
    model.train()
    optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)
    criterion = nn.CrossEntropyLoss(ignore_index=tgt_vocab['<pad>'])
    for epoch in range(epochs):
        total_loss = 0
        for i in range(0, len(xdata), 64):
            src, tgt = collate_fn(xdata[i:i+64], ydata[i:i+64])
            output = model(src, tgt)
            loss = criterion(output[:, 1:].reshape(-1, output.shape[-1]), tgt[:, 1:].reshape(-1))
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        if val_data:
            model.eval()
            val_x, val_y = val_data
            with torch.no_grad():
                src, tgt = collate_fn(val_x, val_y)
                output = model(src, tgt)
                val_loss = criterion(output[:, 1:].reshape(-1, output.shape[-1]), tgt[:, 1:].reshape(-1))
            print(f"Epoch {epoch+1}, Loss: {total_loss:.4f}, Validation Loss: {val_loss.item():.4f}")
            model.train()
        else:
            print(f"Epoch {epoch+1}, Loss: {total_loss:.4f}")

# %%
# Translate
def translate(model, sentence):
    model.eval()
    tokens = tokenize(sentence, src_vocab)
    src = torch.tensor(tokens).unsqueeze(0).to(device)
    enc_outputs, (h, c) = model.encoder(src)
    x = torch.tensor([tgt_vocab['<sos>']]).to(device)
    result = []
    for _ in range(20):
        out, h, c, _ = model.decoder(x, h, c, enc_outputs if model.decoder.attn else None)
        x = out.argmax(1)
        word = tgt_ivocab[x.item()]
        if word == "<eos>":
            break
        result.append(word)
        
    return ' '.join(result)

# %%
# BLEU Evaluation
def evaluate_bleu(model):
    refs, preds = [], []
    for x, y in zip(X_test[:100], Y_test[:100]):
        src_sent = ' '.join([src_ivocab[t.item()] for t in x])
        tgt_sent = [tgt_ivocab[t.item()] for t in y[1:-1]]
        pred = translate(model, src_sent).split()
        refs.append([tgt_sent])
        preds.append(pred)
        
    smoothing = SmoothingFunction().method1
    return corpus_bleu(refs, preds, smoothing_function = smoothing)

# %%
# Attention Visualization
def visualize_attention(model, sentence):
    if MODE == "without_attention":
        print("No Attention to Visualize.")
        return
    model.eval()
    tokens = tokenize(sentence, src_vocab)
    src = torch.tensor(tokens).unsqueeze(0).to(device)
    enc_outputs, (h, c) = model.encoder(src)
    x = torch.tensor([tgt_vocab['<sos>']]).to(device)
    result = []
    attentions = []
    for _ in range(20):
        out, h, c, attn = model.decoder(x, h, c, enc_outputs)
        x = out.argmax(1)
        word = tgt_ivocab[x.item()]
        if word == "<eos>":
            break
        result.append(word)
        attentions.append(attn.squeeze(0).cpu().detach().numpy())
        
    src_words = [src_ivocab[i] for i in tokens]
    fig = plt.figure(figsize = (10, 6))
    ax = fig.add_subplot(111)
    cax = ax.matshow(np.stack(attentions), cmap = "viridis")
    ax.set_xticks(range(len(src_words)))
    ax.set_yticks(range(len(result)))
    ax.set_xticklabels(src_words, rotation = 45)
    ax.set_yticklabels(result)
    ax.set_xlabel("Input Words")
    ax.set_ylabel("Output Words")
    plt.colorbar(cax)
    plt.title(f"Attention ({MODE})")
    plt.show()

# %%
# Load and Prepare Data
pairs = load_data("/kaggle/input/english-to-spanish/spa.txt")

# %%
src_text = [pair[0] for pair in pairs]
tgt_text = [pair[1] for pair in pairs]
src_vocab = build_vocab(src_text)
tgt_vocab = build_vocab(tgt_text)
src_ivocab = {i: w for w, i in src_vocab.items()}
tgt_ivocab = {i: w for w, i in tgt_vocab.items()}

# %%
X, Y = prepare_dataset(pairs, src_vocab, tgt_vocab)

# %%
# 10% Split for Test
X_temp, X_test, Y_temp, Y_test = train_test_split(X, Y, test_size = 0.1)

# 10% Split for Validation
X_train, X_val, Y_train, Y_val = train_test_split(X_temp, Y_temp, test_size = 0.1111)

# %%
# Run all Modes
for MODE in modes:
    print(f"\nRunning Mode: {MODE.upper()}")
    
    encoder = Encoder(len(src_vocab), 256, 512).to(device)
    decoder = Decoder(len(tgt_vocab), 256, 512, MODE).to(device)
    model = Seq2Seq(encoder, decoder).to(device)
    
    train(model, X_train, Y_train, val_data = (X_val, Y_val), epochs = 200)

    print("Translate:", translate(model, "I am happy."))
    print("BLEU Score:", evaluate_bleu(model))
    
    if MODE != "without_attention":
        visualize_attention(model, "I am happy.")
    else:
        print("No Attention Visualization (without_attention Mode).")
# Out:
# Running Mode: WITHOUT_ATTENTION
# Epoch 1, Loss: 822.7927, Validation Loss: 6.2845
# Epoch 2, Loss: 736.8788, Validation Loss: 6.0990
# Epoch 3, Loss: 700.7442, Validation Loss: 6.0365
# Epoch 4, Loss: 664.5208, Validation Loss: 5.9294
# Epoch 5, Loss: 627.3962, Validation Loss: 5.9620
# Epoch 6, Loss: 588.8816, Validation Loss: 5.7213
# Epoch 7, Loss: 548.9410, Validation Loss: 5.7825
# Epoch 8, Loss: 509.1777, Validation Loss: 5.5265
# Epoch 9, Loss: 479.1664, Validation Loss: 5.5653
# Epoch 10, Loss: 447.3971, Validation Loss: 5.5379
# Epoch 11, Loss: 410.7537, Validation Loss: 5.7013
# Epoch 12, Loss: 374.2690, Validation Loss: 5.7484
# Epoch 13, Loss: 346.9150, Validation Loss: 5.8221
# Epoch 14, Loss: 321.6161, Validation Loss: 5.4295
# Epoch 15, Loss: 287.7935, Validation Loss: 5.7055
# Epoch 16, Loss: 265.1605, Validation Loss: 5.7607
# Epoch 17, Loss: 236.3394, Validation Loss: 5.7196
# Epoch 18, Loss: 205.1428, Validation Loss: 5.8904
# Epoch 19, Loss: 181.4534, Validation Loss: 5.9436
# Epoch 20, Loss: 156.8293, Validation Loss: 6.3544
# Epoch 21, Loss: 131.4344, Validation Loss: 6.0388
# Epoch 22, Loss: 113.5411, Validation Loss: 6.1381
# Epoch 23, Loss: 92.7345, Validation Loss: 5.8821
# Epoch 24, Loss: 76.6278, Validation Loss: 6.0167
# Epoch 25, Loss: 61.2751, Validation Loss: 5.8460
# Epoch 26, Loss: 49.5127, Validation Loss: 6.0845
# Epoch 27, Loss: 39.9501, Validation Loss: 6.1166
# Epoch 28, Loss: 32.0606, Validation Loss: 6.5080
# Epoch 29, Loss: 26.4181, Validation Loss: 6.3255
# Epoch 30, Loss: 20.4875, Validation Loss: 6.3847
# Epoch 31, Loss: 16.6312, Validation Loss: 6.5752
# Epoch 32, Loss: 13.6990, Validation Loss: 6.7286
# Epoch 33, Loss: 11.6706, Validation Loss: 6.8577
# Epoch 34, Loss: 9.9107, Validation Loss: 6.5575
# Epoch 35, Loss: 8.3246, Validation Loss: 6.6773
# Epoch 36, Loss: 7.5008, Validation Loss: 6.1284
# Epoch 37, Loss: 6.6718, Validation Loss: 6.1147
# Epoch 38, Loss: 6.2190, Validation Loss: 6.8690
# Epoch 39, Loss: 5.6166, Validation Loss: 7.1939
# Epoch 40, Loss: 5.5373, Validation Loss: 6.8568
# Epoch 41, Loss: 5.0536, Validation Loss: 6.9821
# Epoch 42, Loss: 4.9231, Validation Loss: 7.2178
# Epoch 43, Loss: 4.7814, Validation Loss: 6.5068
# Epoch 44, Loss: 4.6991, Validation Loss: 7.3128
# Epoch 45, Loss: 5.0956, Validation Loss: 6.9817
# Epoch 46, Loss: 6.0505, Validation Loss: 7.1949
# Epoch 47, Loss: 5.4853, Validation Loss: 7.3148
# Epoch 48, Loss: 4.9290, Validation Loss: 7.2849
# Epoch 49, Loss: 5.4664, Validation Loss: 7.2853
# Epoch 50, Loss: 5.6840, Validation Loss: 7.6750
# Epoch 51, Loss: 5.1268, Validation Loss: 6.6901
# Epoch 52, Loss: 5.3256, Validation Loss: 7.4894
# Epoch 53, Loss: 4.8304, Validation Loss: 7.5291
# Epoch 54, Loss: 4.7952, Validation Loss: 7.2871
# Epoch 55, Loss: 4.9044, Validation Loss: 6.9513
# Epoch 56, Loss: 4.9764, Validation Loss: 7.3709
# Epoch 57, Loss: 4.3379, Validation Loss: 7.3399
# Epoch 58, Loss: 4.3967, Validation Loss: 7.4689
# Epoch 59, Loss: 4.3309, Validation Loss: 7.4837
# Epoch 60, Loss: 3.9777, Validation Loss: 7.5468
# Epoch 61, Loss: 3.4107, Validation Loss: 7.2619
# Epoch 62, Loss: 3.5598, Validation Loss: 7.4655
# Epoch 63, Loss: 3.6213, Validation Loss: 7.4781
# Epoch 64, Loss: 3.8006, Validation Loss: 6.8870
# Epoch 65, Loss: 3.0996, Validation Loss: 8.0364
# Epoch 66, Loss: 2.9457, Validation Loss: 7.5584
# Epoch 67, Loss: 2.3804, Validation Loss: 7.1015
# Epoch 68, Loss: 2.5081, Validation Loss: 7.9519
# Epoch 69, Loss: 2.1385, Validation Loss: 7.4766
# Epoch 70, Loss: 2.0761, Validation Loss: 7.8439
# Epoch 71, Loss: 1.8702, Validation Loss: 7.1538
# Epoch 72, Loss: 1.7649, Validation Loss: 8.2418
# Epoch 73, Loss: 1.8755, Validation Loss: 8.0195
# Epoch 74, Loss: 1.5676, Validation Loss: 8.0035
# Epoch 75, Loss: 1.7204, Validation Loss: 7.6961
# Epoch 76, Loss: 1.5262, Validation Loss: 7.6834
# Epoch 77, Loss: 1.7364, Validation Loss: 7.6385
# Epoch 78, Loss: 1.6083, Validation Loss: 8.6570
# Epoch 79, Loss: 1.5335, Validation Loss: 7.4141
# Epoch 80, Loss: 1.4321, Validation Loss: 8.0614
# Epoch 81, Loss: 1.2875, Validation Loss: 8.0961
# Epoch 82, Loss: 1.4835, Validation Loss: 8.2945
# Epoch 83, Loss: 1.4335, Validation Loss: 7.5983
# Epoch 84, Loss: 1.4243, Validation Loss: 7.6244
# Epoch 85, Loss: 1.3612, Validation Loss: 7.3218
# Epoch 86, Loss: 1.3383, Validation Loss: 7.9700
# Epoch 87, Loss: 1.4412, Validation Loss: 8.1637
# Epoch 88, Loss: 1.2453, Validation Loss: 7.8244
# Epoch 89, Loss: 1.2934, Validation Loss: 7.7071
# Epoch 90, Loss: 1.2580, Validation Loss: 7.9940
# Epoch 91, Loss: 1.3496, Validation Loss: 7.2854
# Epoch 92, Loss: 12.0176, Validation Loss: 7.3980
# Epoch 93, Loss: 72.3477, Validation Loss: 7.2947
# Epoch 94, Loss: 24.5920, Validation Loss: 7.6472
# Epoch 95, Loss: 6.0570, Validation Loss: 7.9035
# Epoch 96, Loss: 2.4117, Validation Loss: 7.3689
# Epoch 97, Loss: 1.5217, Validation Loss: 7.9458
# Epoch 98, Loss: 1.4762, Validation Loss: 7.8485
# Epoch 99, Loss: 1.1768, Validation Loss: 7.3066
# Epoch 100, Loss: 1.0701, Validation Loss: 7.1448
# Epoch 101, Loss: 1.0420, Validation Loss: 7.3703
# Epoch 102, Loss: 1.0878, Validation Loss: 7.5661
# Epoch 103, Loss: 1.0261, Validation Loss: 8.1479
# Epoch 104, Loss: 0.9671, Validation Loss: 7.3218
# Epoch 105, Loss: 0.8984, Validation Loss: 7.4506
# Epoch 106, Loss: 0.9198, Validation Loss: 8.7162
# Epoch 107, Loss: 0.9256, Validation Loss: 7.8090
# Epoch 108, Loss: 1.0032, Validation Loss: 7.8292
# Epoch 109, Loss: 1.0414, Validation Loss: 7.9803
# Epoch 110, Loss: 1.0102, Validation Loss: 7.4976
# Epoch 111, Loss: 0.8383, Validation Loss: 7.5285
# Epoch 112, Loss: 0.9004, Validation Loss: 8.1115
# Epoch 113, Loss: 1.1606, Validation Loss: 7.7568
# Epoch 114, Loss: 1.1236, Validation Loss: 7.9848
# Epoch 115, Loss: 0.9919, Validation Loss: 7.4093
# Epoch 116, Loss: 0.9737, Validation Loss: 7.9512
# Epoch 117, Loss: 0.9362, Validation Loss: 7.6871
# Epoch 118, Loss: 0.8997, Validation Loss: 7.3514
# Epoch 119, Loss: 0.9220, Validation Loss: 7.6884
# Epoch 120, Loss: 0.9659, Validation Loss: 7.5471
# Epoch 121, Loss: 0.9889, Validation Loss: 7.8941
# Epoch 122, Loss: 1.1488, Validation Loss: 7.3861
# Epoch 123, Loss: 1.2042, Validation Loss: 8.3059
# Epoch 124, Loss: 1.3555, Validation Loss: 8.1156
# Epoch 125, Loss: 1.3366, Validation Loss: 7.2351
# Epoch 126, Loss: 1.4460, Validation Loss: 7.5817
# Epoch 127, Loss: 1.2230, Validation Loss: 8.9945
# Epoch 128, Loss: 1.1123, Validation Loss: 8.1862
# Epoch 129, Loss: 1.4646, Validation Loss: 7.2698
# Epoch 130, Loss: 1.7692, Validation Loss: 7.6382
# Epoch 131, Loss: 12.2216, Validation Loss: 7.7432
# Epoch 132, Loss: 33.6093, Validation Loss: 7.5260
# Epoch 133, Loss: 14.7068, Validation Loss: 7.1509
# Epoch 134, Loss: 4.6109, Validation Loss: 7.3601
# Epoch 135, Loss: 1.4363, Validation Loss: 7.7404
# Epoch 136, Loss: 1.0151, Validation Loss: 7.6737
# Epoch 137, Loss: 0.9798, Validation Loss: 7.4855
# Epoch 138, Loss: 0.7987, Validation Loss: 7.6536
# Epoch 139, Loss: 0.8428, Validation Loss: 7.7946
# Epoch 140, Loss: 0.7017, Validation Loss: 8.7361
# Epoch 141, Loss: 0.7980, Validation Loss: 7.7829
# Epoch 142, Loss: 0.8436, Validation Loss: 7.9097
# Epoch 143, Loss: 0.7317, Validation Loss: 7.2618
# Epoch 144, Loss: 0.8379, Validation Loss: 7.3406
# Epoch 145, Loss: 0.6784, Validation Loss: 7.6063
# Epoch 146, Loss: 0.6930, Validation Loss: 7.6340
# Epoch 147, Loss: 0.6988, Validation Loss: 7.9404
# Epoch 148, Loss: 0.7458, Validation Loss: 8.8921
# Epoch 149, Loss: 0.7025, Validation Loss: 8.1552
# Epoch 150, Loss: 0.8073, Validation Loss: 8.1643
# Epoch 151, Loss: 0.7352, Validation Loss: 7.6530
# Epoch 152, Loss: 0.6762, Validation Loss: 8.0028
# Epoch 153, Loss: 0.5785, Validation Loss: 8.1503
# Epoch 154, Loss: 0.7581, Validation Loss: 8.2202
# Epoch 155, Loss: 0.6868, Validation Loss: 8.7313
# Epoch 156, Loss: 0.5953, Validation Loss: 8.9607
# Epoch 157, Loss: 0.8359, Validation Loss: 8.5434
# Epoch 158, Loss: 0.7470, Validation Loss: 8.2229
# Epoch 159, Loss: 0.6252, Validation Loss: 8.4438
# Epoch 160, Loss: 0.7339, Validation Loss: 7.3291
# Epoch 161, Loss: 0.8267, Validation Loss: 7.7495
# Epoch 162, Loss: 0.8194, Validation Loss: 7.5106
# Epoch 163, Loss: 1.0278, Validation Loss: 7.9812
# Epoch 164, Loss: 1.2528, Validation Loss: 8.4872
# Epoch 165, Loss: 1.4877, Validation Loss: 8.8343
# Epoch 166, Loss: 2.8528, Validation Loss: 8.5859
# Epoch 167, Loss: 10.0330, Validation Loss: 9.0370
# Epoch 168, Loss: 22.5247, Validation Loss: 8.6460
# Epoch 169, Loss: 10.8203, Validation Loss: 7.1578
# Epoch 170, Loss: 3.6905, Validation Loss: 8.3856
# Epoch 171, Loss: 1.2529, Validation Loss: 8.1576
# Epoch 172, Loss: 0.9192, Validation Loss: 7.8627
# Epoch 173, Loss: 0.6947, Validation Loss: 8.1377
# Epoch 174, Loss: 0.6397, Validation Loss: 8.2826
# Epoch 175, Loss: 0.5700, Validation Loss: 8.1641
# Epoch 176, Loss: 0.6137, Validation Loss: 8.8346
# Epoch 177, Loss: 0.6182, Validation Loss: 8.0938
# Epoch 178, Loss: 0.5953, Validation Loss: 8.0076
# Epoch 179, Loss: 0.5676, Validation Loss: 8.1085
# Epoch 180, Loss: 0.6969, Validation Loss: 8.3903
# Epoch 181, Loss: 0.5703, Validation Loss: 8.9895
# Epoch 182, Loss: 0.5184, Validation Loss: 8.8843
# Epoch 183, Loss: 0.5431, Validation Loss: 8.7589
# Epoch 184, Loss: 0.5565, Validation Loss: 7.8788
# Epoch 185, Loss: 0.5003, Validation Loss: 8.3617
# Epoch 186, Loss: 0.4922, Validation Loss: 8.5963
# Epoch 187, Loss: 0.4838, Validation Loss: 7.6498
# Epoch 188, Loss: 0.5256, Validation Loss: 9.2616
# Epoch 189, Loss: 0.5684, Validation Loss: 7.7612
# Epoch 190, Loss: 0.5187, Validation Loss: 8.2852
# Epoch 191, Loss: 0.6322, Validation Loss: 8.3195
# Epoch 192, Loss: 0.6742, Validation Loss: 9.0586
# Epoch 193, Loss: 0.6528, Validation Loss: 8.4924
# Epoch 194, Loss: 0.8144, Validation Loss: 8.5658
# Epoch 195, Loss: 0.7922, Validation Loss: 7.7223
# Epoch 196, Loss: 0.6680, Validation Loss: 9.7031
# Epoch 197, Loss: 0.6213, Validation Loss: 8.6286
# Epoch 198, Loss: 0.6734, Validation Loss: 8.0013
# Epoch 199, Loss: 0.5242, Validation Loss: 8.6768
# Epoch 200, Loss: 0.4907, Validation Loss: 9.3902
# Translate: hace feliz.
# BLEU Score: 0.036097136971705884
# No Attention Visualization (without_attention Mode).
#
# Running Mode: BAHDANAU
# Epoch 1, Loss: 802.3888, Validation Loss: 5.8960
# Epoch 2, Loss: 662.4263, Validation Loss: 5.6401
# Epoch 3, Loss: 569.6978, Validation Loss: 5.4359
# Epoch 4, Loss: 470.9808, Validation Loss: 5.2420
# Epoch 5, Loss: 368.2708, Validation Loss: 5.2733
# Epoch 6, Loss: 282.6932, Validation Loss: 5.2787
# Epoch 7, Loss: 222.8610, Validation Loss: 5.1949
# Epoch 8, Loss: 182.4120, Validation Loss: 5.3375
# Epoch 9, Loss: 156.2232, Validation Loss: 5.4055
# Epoch 10, Loss: 128.5978, Validation Loss: 5.6135
# Epoch 11, Loss: 101.1138, Validation Loss: 5.3841
# Epoch 12, Loss: 82.2791, Validation Loss: 5.1952
# Epoch 13, Loss: 67.2376, Validation Loss: 5.3238
# Epoch 14, Loss: 53.4303, Validation Loss: 5.4608
# Epoch 15, Loss: 41.4455, Validation Loss: 5.7559
# Epoch 16, Loss: 35.9246, Validation Loss: 6.0410
# Epoch 17, Loss: 28.2801, Validation Loss: 5.8870
# Epoch 18, Loss: 22.9553, Validation Loss: 5.3867
# Epoch 19, Loss: 19.9551, Validation Loss: 6.1206
# Epoch 20, Loss: 17.0411, Validation Loss: 5.9655
# Epoch 21, Loss: 14.1834, Validation Loss: 5.5073
# Epoch 22, Loss: 12.3809, Validation Loss: 6.0542
# Epoch 23, Loss: 11.1539, Validation Loss: 5.8907
# Epoch 24, Loss: 9.8117, Validation Loss: 5.6019
# Epoch 25, Loss: 8.8894, Validation Loss: 5.3855
# Epoch 26, Loss: 8.1260, Validation Loss: 6.0257
# Epoch 27, Loss: 7.6110, Validation Loss: 5.8800
# Epoch 28, Loss: 6.8887, Validation Loss: 6.1876
# Epoch 29, Loss: 6.7967, Validation Loss: 5.7259
# Epoch 30, Loss: 6.5410, Validation Loss: 5.8750
# Epoch 31, Loss: 6.7601, Validation Loss: 6.2938
# Epoch 32, Loss: 7.8867, Validation Loss: 6.1133
# Epoch 33, Loss: 9.9605, Validation Loss: 5.9622
# Epoch 34, Loss: 11.8829, Validation Loss: 5.7926
# Epoch 35, Loss: 15.0795, Validation Loss: 5.7179
# Epoch 36, Loss: 17.0753, Validation Loss: 5.7454
# Epoch 37, Loss: 19.2588, Validation Loss: 5.6448
# Epoch 38, Loss: 16.9523, Validation Loss: 5.8660
# Epoch 39, Loss: 13.5998, Validation Loss: 6.8710
# Epoch 40, Loss: 9.0731, Validation Loss: 5.9877
# Epoch 41, Loss: 6.1663, Validation Loss: 6.5297
# Epoch 42, Loss: 4.3807, Validation Loss: 5.8326
# Epoch 43, Loss: 3.9349, Validation Loss: 5.8638
# Epoch 44, Loss: 3.2401, Validation Loss: 6.1207
# Epoch 45, Loss: 2.7928, Validation Loss: 6.3500
# Epoch 46, Loss: 2.8500, Validation Loss: 6.7326
# Epoch 47, Loss: 2.7427, Validation Loss: 6.0311
# Epoch 48, Loss: 2.4677, Validation Loss: 5.9027
# Epoch 49, Loss: 2.4756, Validation Loss: 6.3658
# Epoch 50, Loss: 2.2345, Validation Loss: 5.8562
# Epoch 51, Loss: 2.1641, Validation Loss: 6.0484
# Epoch 52, Loss: 2.3565, Validation Loss: 6.3688
# Epoch 53, Loss: 2.2033, Validation Loss: 6.0768
# Epoch 54, Loss: 2.3838, Validation Loss: 6.4956
# Epoch 55, Loss: 2.3688, Validation Loss: 6.4031
# Epoch 56, Loss: 2.4718, Validation Loss: 6.8283
# Epoch 57, Loss: 5.6398, Validation Loss: 6.2365
# Epoch 58, Loss: 21.8542, Validation Loss: 5.8388
# Epoch 59, Loss: 46.2158, Validation Loss: 6.5160
# Epoch 60, Loss: 39.4610, Validation Loss: 6.1425
# Epoch 61, Loss: 19.6904, Validation Loss: 6.2369
# Epoch 62, Loss: 9.1698, Validation Loss: 5.8061
# Epoch 63, Loss: 4.5020, Validation Loss: 6.8243
# Epoch 64, Loss: 2.6957, Validation Loss: 6.3291
# Epoch 65, Loss: 2.1987, Validation Loss: 6.4045
# Epoch 66, Loss: 1.9301, Validation Loss: 6.0629
# Epoch 67, Loss: 2.0106, Validation Loss: 5.9664
# Epoch 68, Loss: 2.0569, Validation Loss: 6.5524
# Epoch 69, Loss: 1.8921, Validation Loss: 6.2313
# Epoch 70, Loss: 1.7935, Validation Loss: 6.3924
# Epoch 71, Loss: 1.6682, Validation Loss: 6.2193
# Epoch 72, Loss: 1.7207, Validation Loss: 6.6523
# Epoch 73, Loss: 1.5390, Validation Loss: 6.6760
# Epoch 74, Loss: 1.5935, Validation Loss: 6.3675
# Epoch 75, Loss: 1.5651, Validation Loss: 6.4455
# Epoch 76, Loss: 1.5763, Validation Loss: 6.3787
# Epoch 77, Loss: 1.6504, Validation Loss: 6.7421
# Epoch 78, Loss: 2.0387, Validation Loss: 6.6481
# Epoch 79, Loss: 1.7577, Validation Loss: 6.1030
# Epoch 80, Loss: 1.6018, Validation Loss: 7.2562
# Epoch 81, Loss: 1.5553, Validation Loss: 6.3843
# Epoch 82, Loss: 1.6798, Validation Loss: 6.3957
# Epoch 83, Loss: 1.6307, Validation Loss: 6.2353
# Epoch 84, Loss: 1.6376, Validation Loss: 6.3852
# Epoch 85, Loss: 1.8240, Validation Loss: 6.2795
# Epoch 86, Loss: 2.2931, Validation Loss: 6.4150
# Epoch 87, Loss: 4.2916, Validation Loss: 6.3692
# Epoch 88, Loss: 18.3507, Validation Loss: 6.0058
# Epoch 89, Loss: 34.2046, Validation Loss: 5.9884
# Epoch 90, Loss: 24.4145, Validation Loss: 6.0554
# Epoch 91, Loss: 12.7055, Validation Loss: 6.0746
# Epoch 92, Loss: 5.5392, Validation Loss: 6.9712
# Epoch 93, Loss: 2.5020, Validation Loss: 6.4372
# Epoch 94, Loss: 1.9608, Validation Loss: 6.3247
# Epoch 95, Loss: 1.5677, Validation Loss: 6.2312
# Epoch 96, Loss: 1.4433, Validation Loss: 6.4605
# Epoch 97, Loss: 1.4104, Validation Loss: 7.6406
# Epoch 98, Loss: 1.3187, Validation Loss: 6.4846
# Epoch 99, Loss: 1.2997, Validation Loss: 5.9834
# Epoch 100, Loss: 1.2473, Validation Loss: 6.5476
# Epoch 101, Loss: 1.1439, Validation Loss: 6.5314
# Epoch 102, Loss: 1.2899, Validation Loss: 6.6816
# Epoch 103, Loss: 1.1970, Validation Loss: 6.2579
# Epoch 104, Loss: 1.2189, Validation Loss: 6.3875
# Epoch 105, Loss: 1.1588, Validation Loss: 6.5460
# Epoch 106, Loss: 0.9801, Validation Loss: 6.5825
# Epoch 107, Loss: 0.9370, Validation Loss: 6.2674
# Epoch 108, Loss: 1.0372, Validation Loss: 6.9638
# Epoch 109, Loss: 1.2200, Validation Loss: 7.4142
# Epoch 110, Loss: 1.0878, Validation Loss: 6.8001
# Epoch 111, Loss: 1.2397, Validation Loss: 7.4531
# Epoch 112, Loss: 1.4663, Validation Loss: 6.3336
# Epoch 113, Loss: 1.5350, Validation Loss: 6.5848
# Epoch 114, Loss: 1.5462, Validation Loss: 6.2696
# Epoch 115, Loss: 1.5868, Validation Loss: 6.3433
# Epoch 116, Loss: 1.9333, Validation Loss: 6.3354
# Epoch 117, Loss: 2.6519, Validation Loss: 6.8543
# Epoch 118, Loss: 5.8887, Validation Loss: 7.0228
# Epoch 119, Loss: 15.5713, Validation Loss: 6.2314
# Epoch 120, Loss: 22.3630, Validation Loss: 7.1097
# Epoch 121, Loss: 16.8394, Validation Loss: 5.8908
# Epoch 122, Loss: 7.9269, Validation Loss: 6.1108
# Epoch 123, Loss: 3.4127, Validation Loss: 6.5283
# Epoch 124, Loss: 1.8805, Validation Loss: 7.0814
# Epoch 125, Loss: 1.4316, Validation Loss: 6.9365
# Epoch 126, Loss: 1.1136, Validation Loss: 6.5037
# Epoch 127, Loss: 0.8998, Validation Loss: 6.3919
# Epoch 128, Loss: 0.8377, Validation Loss: 6.3018
# Epoch 129, Loss: 0.8825, Validation Loss: 6.6910
# Epoch 130, Loss: 0.7359, Validation Loss: 7.5190
# Epoch 131, Loss: 0.7486, Validation Loss: 7.3828
# Epoch 132, Loss: 0.7785, Validation Loss: 6.2535
# Epoch 133, Loss: 1.0100, Validation Loss: 6.4200
# Epoch 134, Loss: 0.8561, Validation Loss: 6.8856
# Epoch 135, Loss: 0.7915, Validation Loss: 7.6335
# Epoch 136, Loss: 0.7285, Validation Loss: 7.2488
# Epoch 137, Loss: 0.9410, Validation Loss: 7.2109
# Epoch 138, Loss: 0.9611, Validation Loss: 7.1450
# Epoch 139, Loss: 1.0551, Validation Loss: 6.3944
# Epoch 140, Loss: 0.8760, Validation Loss: 6.6744
# Epoch 141, Loss: 1.0128, Validation Loss: 8.0635
# Epoch 142, Loss: 1.2724, Validation Loss: 6.4972
# Epoch 143, Loss: 1.3422, Validation Loss: 7.0150
# Epoch 144, Loss: 1.1756, Validation Loss: 6.7627
# Epoch 145, Loss: 0.9774, Validation Loss: 6.8328
# Epoch 146, Loss: 0.9359, Validation Loss: 7.5511
# Epoch 147, Loss: 1.0689, Validation Loss: 6.5138
# Epoch 148, Loss: 0.9251, Validation Loss: 6.8849
# Epoch 149, Loss: 0.7302, Validation Loss: 7.1148
# Epoch 150, Loss: 0.7363, Validation Loss: 7.5388
# Epoch 151, Loss: 0.6348, Validation Loss: 6.5894
# Epoch 152, Loss: 0.7046, Validation Loss: 7.0362
# Epoch 153, Loss: 1.0395, Validation Loss: 6.3556
# Epoch 154, Loss: 1.1468, Validation Loss: 6.2535
# Epoch 155, Loss: 4.9681, Validation Loss: 7.2111
# Epoch 156, Loss: 20.5960, Validation Loss: 7.4242
# Epoch 157, Loss: 25.0277, Validation Loss: 6.6712
# Epoch 158, Loss: 11.0565, Validation Loss: 6.2830
# Epoch 159, Loss: 3.7668, Validation Loss: 7.2504
# Epoch 160, Loss: 1.5328, Validation Loss: 7.0825
# Epoch 161, Loss: 0.9252, Validation Loss: 6.5202
# Epoch 162, Loss: 0.7101, Validation Loss: 7.0761
# Epoch 163, Loss: 0.5478, Validation Loss: 6.6961
# Epoch 164, Loss: 0.5826, Validation Loss: 6.7983
# Epoch 165, Loss: 0.6740, Validation Loss: 6.5506
# Epoch 166, Loss: 0.6804, Validation Loss: 6.5581
# Epoch 167, Loss: 0.6754, Validation Loss: 7.1060
# Epoch 168, Loss: 0.5966, Validation Loss: 6.5897
# Epoch 169, Loss: 0.5114, Validation Loss: 7.1328
# Epoch 170, Loss: 0.5107, Validation Loss: 6.5949
# Epoch 171, Loss: 0.5383, Validation Loss: 6.6934
# Epoch 172, Loss: 0.4867, Validation Loss: 6.3606
# Epoch 173, Loss: 0.5680, Validation Loss: 6.5709
# Epoch 174, Loss: 0.4546, Validation Loss: 7.0757
# Epoch 175, Loss: 0.5552, Validation Loss: 6.8797
# Epoch 176, Loss: 0.6224, Validation Loss: 6.8823
# Epoch 177, Loss: 0.5094, Validation Loss: 7.1544
# Epoch 178, Loss: 0.5325, Validation Loss: 6.9582
# Epoch 179, Loss: 0.7054, Validation Loss: 6.9396
# Epoch 180, Loss: 0.6920, Validation Loss: 6.9248
# Epoch 181, Loss: 0.8161, Validation Loss: 6.3266
# Epoch 182, Loss: 0.6679, Validation Loss: 6.8432
# Epoch 183, Loss: 0.6791, Validation Loss: 7.2761
# Epoch 184, Loss: 0.7588, Validation Loss: 7.2767
# Epoch 185, Loss: 0.7745, Validation Loss: 7.5534
# Epoch 186, Loss: 0.9682, Validation Loss: 7.0993
# Epoch 187, Loss: 1.6168, Validation Loss: 7.1902
# Epoch 188, Loss: 4.5099, Validation Loss: 6.7478
# Epoch 189, Loss: 12.4520, Validation Loss: 6.9001
# Epoch 190, Loss: 14.4516, Validation Loss: 6.5013
# Epoch 191, Loss: 8.4128, Validation Loss: 7.2197
# Epoch 192, Loss: 3.6950, Validation Loss: 6.5683
# Epoch 193, Loss: 1.5257, Validation Loss: 7.1084
# Epoch 194, Loss: 0.7793, Validation Loss: 6.5023
# Epoch 195, Loss: 0.4643, Validation Loss: 7.1338
# Epoch 196, Loss: 0.4992, Validation Loss: 6.3561
# Epoch 197, Loss: 0.4205, Validation Loss: 6.6632
# Epoch 198, Loss: 0.4298, Validation Loss: 6.7390
# Epoch 199, Loss: 0.4209, Validation Loss: 7.2684
# Epoch 200, Loss: 0.4488, Validation Loss: 6.8114
# Translate: me estoy feliz.
# BLEU Score: 0.0881088586545416
# Running Mode: LUONG
# Epoch 1, Loss: 807.4284, Validation Loss: 6.0840
# Epoch 2, Loss: 671.6562, Validation Loss: 5.4712
# Epoch 3, Loss: 564.2708, Validation Loss: 5.2840
# Epoch 4, Loss: 459.0129, Validation Loss: 5.1535
# Epoch 5, Loss: 363.8817, Validation Loss: 5.1356
# Epoch 6, Loss: 288.5161, Validation Loss: 4.9811
# Epoch 7, Loss: 240.0437, Validation Loss: 5.0791
# Epoch 8, Loss: 209.0000, Validation Loss: 5.0395
# Epoch 9, Loss: 184.7484, Validation Loss: 4.9791
# Epoch 10, Loss: 159.0501, Validation Loss: 5.0898
# Epoch 11, Loss: 135.2362, Validation Loss: 5.1459
# Epoch 12, Loss: 116.8832, Validation Loss: 5.1268
# Epoch 13, Loss: 95.3992, Validation Loss: 5.3432
# Epoch 14, Loss: 79.2212, Validation Loss: 5.2625
# Epoch 15, Loss: 65.3557, Validation Loss: 5.1651
# Epoch 16, Loss: 57.2298, Validation Loss: 5.2911
# Epoch 17, Loss: 47.1814, Validation Loss: 5.0983
# Epoch 18, Loss: 38.4601, Validation Loss: 5.5293
# Epoch 19, Loss: 33.2580, Validation Loss: 5.6189
# Epoch 20, Loss: 29.4328, Validation Loss: 5.3364
# Epoch 21, Loss: 29.0010, Validation Loss: 5.3856
# Epoch 22, Loss: 22.5270, Validation Loss: 5.8225
# Epoch 23, Loss: 18.5766, Validation Loss: 5.5922
# Epoch 24, Loss: 18.2844, Validation Loss: 5.8983
# Epoch 25, Loss: 17.5858, Validation Loss: 5.6075
# Epoch 26, Loss: 15.5370, Validation Loss: 5.5570
# Epoch 27, Loss: 13.7029, Validation Loss: 5.7580
# Epoch 28, Loss: 12.5023, Validation Loss: 5.7742
# Epoch 29, Loss: 10.4181, Validation Loss: 5.7315
# Epoch 30, Loss: 15.1026, Validation Loss: 5.9530
# Epoch 31, Loss: 17.9675, Validation Loss: 5.5890
# Epoch 32, Loss: 16.6140, Validation Loss: 5.8672
# Epoch 33, Loss: 12.6254, Validation Loss: 6.4489
# Epoch 34, Loss: 11.0770, Validation Loss: 5.5481
# Epoch 35, Loss: 9.5916, Validation Loss: 5.6529
# Epoch 36, Loss: 9.9011, Validation Loss: 5.8874
# Epoch 37, Loss: 10.1437, Validation Loss: 6.0999
# Epoch 38, Loss: 8.9860, Validation Loss: 5.4618
# Epoch 39, Loss: 7.8116, Validation Loss: 5.7866
# Epoch 40, Loss: 8.1306, Validation Loss: 5.9451
# Epoch 41, Loss: 7.7806, Validation Loss: 6.1277
# Epoch 42, Loss: 7.1431, Validation Loss: 6.5956
# Epoch 43, Loss: 11.7478, Validation Loss: 6.6962
# Epoch 44, Loss: 12.0609, Validation Loss: 6.0719
# Epoch 45, Loss: 10.1318, Validation Loss: 5.9027
# Epoch 46, Loss: 9.9231, Validation Loss: 6.4061
# Epoch 47, Loss: 13.2911, Validation Loss: 6.1258
# Epoch 48, Loss: 13.3764, Validation Loss: 6.3760
# Epoch 49, Loss: 11.9477, Validation Loss: 6.6930
# Epoch 50, Loss: 9.4749, Validation Loss: 6.1646
# Epoch 51, Loss: 8.6533, Validation Loss: 6.4732
# Epoch 52, Loss: 10.5206, Validation Loss: 6.1884
# Epoch 53, Loss: 9.6811, Validation Loss: 6.3615
# Epoch 54, Loss: 10.8948, Validation Loss: 6.0186
# Epoch 55, Loss: 12.6782, Validation Loss: 5.9865
# Epoch 56, Loss: 9.5150, Validation Loss: 6.6604
# Epoch 57, Loss: 7.5935, Validation Loss: 6.6440
# Epoch 58, Loss: 7.3205, Validation Loss: 6.4513
# Epoch 59, Loss: 6.8555, Validation Loss: 7.0165
# Epoch 60, Loss: 4.5312, Validation Loss: 6.3724
# Epoch 61, Loss: 3.7180, Validation Loss: 6.8047
# Epoch 62, Loss: 3.2893, Validation Loss: 6.4985
# Epoch 63, Loss: 3.3169, Validation Loss: 6.3805
# Epoch 64, Loss: 3.4559, Validation Loss: 6.5375
# Epoch 65, Loss: 3.5548, Validation Loss: 5.9771
# Epoch 66, Loss: 3.5796, Validation Loss: 6.3553
# Epoch 67, Loss: 3.9115, Validation Loss: 6.6883
# Epoch 68, Loss: 6.5282, Validation Loss: 6.1074
# Epoch 69, Loss: 14.0018, Validation Loss: 6.1914
# Epoch 70, Loss: 14.9046, Validation Loss: 6.0837
# Epoch 71, Loss: 12.1099, Validation Loss: 6.3961
# Epoch 72, Loss: 9.6797, Validation Loss: 6.1726
# Epoch 73, Loss: 6.6012, Validation Loss: 6.4544
# Epoch 74, Loss: 6.9234, Validation Loss: 6.2830
# Epoch 75, Loss: 5.8950, Validation Loss: 6.5518
# Epoch 76, Loss: 4.9145, Validation Loss: 6.4378
# Epoch 77, Loss: 4.0611, Validation Loss: 6.9983
# Epoch 78, Loss: 3.0347, Validation Loss: 6.7877
# Epoch 79, Loss: 2.4456, Validation Loss: 6.5270
# Epoch 80, Loss: 2.7237, Validation Loss: 6.2815
# Epoch 81, Loss: 2.3356, Validation Loss: 6.5992
# Epoch 82, Loss: 2.7673, Validation Loss: 6.4712
# Epoch 83, Loss: 5.3362, Validation Loss: 5.8629
# Epoch 84, Loss: 8.7860, Validation Loss: 6.3985
# Epoch 85, Loss: 13.6298, Validation Loss: 7.0507
# Epoch 86, Loss: 13.9394, Validation Loss: 6.4549
# Epoch 87, Loss: 10.3082, Validation Loss: 6.1068
# Epoch 88, Loss: 8.5956, Validation Loss: 7.2255
# Epoch 89, Loss: 4.9979, Validation Loss: 6.5608
# Epoch 90, Loss: 3.8522, Validation Loss: 6.4430
# Epoch 91, Loss: 2.5887, Validation Loss: 6.5361
# Epoch 92, Loss: 2.6916, Validation Loss: 6.5121
# Epoch 93, Loss: 2.5490, Validation Loss: 7.1453
# Epoch 94, Loss: 2.2890, Validation Loss: 6.4540
# Epoch 95, Loss: 1.9037, Validation Loss: 7.1588
# Epoch 96, Loss: 1.9614, Validation Loss: 6.8628
# Epoch 97, Loss: 1.7963, Validation Loss: 6.8436
# Epoch 98, Loss: 1.9351, Validation Loss: 7.1778
# Epoch 99, Loss: 1.8340, Validation Loss: 6.6470
# Epoch 100, Loss: 1.6548, Validation Loss: 6.6479
# Epoch 101, Loss: 1.8679, Validation Loss: 6.5178
# Epoch 102, Loss: 1.6042, Validation Loss: 6.9001
# Epoch 103, Loss: 1.7084, Validation Loss: 6.1596
# Epoch 104, Loss: 1.4338, Validation Loss: 6.7835
# Epoch 105, Loss: 1.3965, Validation Loss: 6.7873
# Epoch 106, Loss: 1.5052, Validation Loss: 7.2160
# Epoch 107, Loss: 1.5909, Validation Loss: 6.6934
# Epoch 108, Loss: 1.2612, Validation Loss: 6.3683
# Epoch 109, Loss: 1.6585, Validation Loss: 6.2474
# Epoch 110, Loss: 1.7856, Validation Loss: 7.2499
# Epoch 111, Loss: 1.5066, Validation Loss: 6.7581
# Epoch 112, Loss: 10.1572, Validation Loss: 6.0959
# Epoch 113, Loss: 34.6127, Validation Loss: 6.5249
# Epoch 114, Loss: 32.9736, Validation Loss: 7.4034
# Epoch 115, Loss: 19.9268, Validation Loss: 6.5885
# Epoch 116, Loss: 10.5719, Validation Loss: 7.0855
# Epoch 117, Loss: 4.9682, Validation Loss: 7.3288
# Epoch 118, Loss: 4.1375, Validation Loss: 6.9950
# Epoch 119, Loss: 3.5174, Validation Loss: 7.0558
# Epoch 120, Loss: 2.4657, Validation Loss: 6.5954
# Epoch 121, Loss: 2.1590, Validation Loss: 6.9315
# Epoch 122, Loss: 1.8710, Validation Loss: 7.0886
# Epoch 123, Loss: 1.5913, Validation Loss: 6.7243
# Epoch 124, Loss: 1.5659, Validation Loss: 6.8019
# Epoch 125, Loss: 1.3926, Validation Loss: 6.7251
# Epoch 126, Loss: 1.3393, Validation Loss: 6.8373
# Epoch 127, Loss: 1.4468, Validation Loss: 7.2795
# Epoch 128, Loss: 1.3395, Validation Loss: 7.0491
# Epoch 129, Loss: 1.2478, Validation Loss: 6.9979
# Epoch 130, Loss: 1.2171, Validation Loss: 7.0309
# Epoch 131, Loss: 1.3528, Validation Loss: 6.3868
# Epoch 132, Loss: 1.3592, Validation Loss: 7.2524
# Epoch 133, Loss: 1.3578, Validation Loss: 6.5397
# Epoch 134, Loss: 1.4179, Validation Loss: 7.0749
# Epoch 135, Loss: 1.3970, Validation Loss: 7.3317
# Epoch 136, Loss: 1.4426, Validation Loss: 7.2479
# Epoch 137, Loss: 1.5545, Validation Loss: 6.8623
# Epoch 138, Loss: 1.5717, Validation Loss: 6.8417
# Epoch 139, Loss: 1.4150, Validation Loss: 7.2898
# Epoch 140, Loss: 1.3866, Validation Loss: 7.0211
# Epoch 141, Loss: 4.7057, Validation Loss: 6.9737
# Epoch 142, Loss: 9.9380, Validation Loss: 6.8346
# Epoch 143, Loss: 23.2141, Validation Loss: 7.0563
# Epoch 144, Loss: 20.1494, Validation Loss: 7.1273
# Epoch 145, Loss: 11.9188, Validation Loss: 6.5046
# Epoch 146, Loss: 6.7840, Validation Loss: 6.6098
# Epoch 147, Loss: 3.5499, Validation Loss: 6.3897
# Epoch 148, Loss: 2.7950, Validation Loss: 7.2268
# Epoch 149, Loss: 1.9251, Validation Loss: 6.4661
# Epoch 150, Loss: 1.7196, Validation Loss: 8.2303
# Epoch 151, Loss: 1.1057, Validation Loss: 7.0644
# Epoch 152, Loss: 1.3789, Validation Loss: 6.5649
# Epoch 153, Loss: 2.4209, Validation Loss: 6.4694
# Epoch 154, Loss: 1.9688, Validation Loss: 7.4785
# Epoch 155, Loss: 1.9147, Validation Loss: 7.0800
# Epoch 156, Loss: 1.3546, Validation Loss: 6.8740
# Epoch 157, Loss: 2.2744, Validation Loss: 7.3817
# Epoch 158, Loss: 2.8193, Validation Loss: 7.6361
# Epoch 159, Loss: 5.4891, Validation Loss: 7.5666
# Epoch 160, Loss: 6.3404, Validation Loss: 7.0199
# Epoch 161, Loss: 4.9820, Validation Loss: 6.9303
# Epoch 162, Loss: 3.5225, Validation Loss: 7.4796
# Epoch 163, Loss: 2.9671, Validation Loss: 6.8492
# Epoch 164, Loss: 2.9180, Validation Loss: 6.7570
# Epoch 165, Loss: 3.3075, Validation Loss: 6.8768
# Epoch 166, Loss: 2.7462, Validation Loss: 7.5222
# Epoch 167, Loss: 2.6437, Validation Loss: 6.8049
# Epoch 168, Loss: 1.7588, Validation Loss: 7.6248
# Epoch 169, Loss: 1.3247, Validation Loss: 7.0598
# Epoch 170, Loss: 1.3034, Validation Loss: 8.2672
# Epoch 171, Loss: 1.0707, Validation Loss: 7.2122
# Epoch 172, Loss: 1.0160, Validation Loss: 7.3784
# Epoch 173, Loss: 0.8817, Validation Loss: 7.4529
# Epoch 174, Loss: 1.0426, Validation Loss: 7.1256
# Epoch 175, Loss: 0.8779, Validation Loss: 7.5620
# Epoch 176, Loss: 0.7932, Validation Loss: 6.9647
# Epoch 177, Loss: 0.8425, Validation Loss: 7.0557
# Epoch 178, Loss: 0.8722, Validation Loss: 7.1575
# Epoch 179, Loss: 0.9471, Validation Loss: 6.9446
# Epoch 180, Loss: 0.8892, Validation Loss: 7.5000
# Epoch 181, Loss: 0.8157, Validation Loss: 6.7689
# Epoch 182, Loss: 0.8061, Validation Loss: 8.4300
# Epoch 183, Loss: 0.8922, Validation Loss: 7.1190
# Epoch 184, Loss: 0.9642, Validation Loss: 7.4422
# Epoch 185, Loss: 0.8064, Validation Loss: 7.4977
# Epoch 186, Loss: 0.7964, Validation Loss: 7.2736
# Epoch 187, Loss: 0.7977, Validation Loss: 7.6856
# Epoch 188, Loss: 0.8946, Validation Loss: 7.8425
# Epoch 189, Loss: 3.9700, Validation Loss: 7.1059
# Epoch 190, Loss: 22.3952, Validation Loss: 7.2874
# Epoch 191, Loss: 34.7831, Validation Loss: 6.9705
# Epoch 192, Loss: 23.1972, Validation Loss: 7.0741
# Epoch 193, Loss: 9.6529, Validation Loss: 7.4124
# Epoch 194, Loss: 5.4369, Validation Loss: 6.7343
# Epoch 195, Loss: 2.3917, Validation Loss: 6.8394
# Epoch 196, Loss: 1.6604, Validation Loss: 6.4746
# Epoch 197, Loss: 1.2652, Validation Loss: 7.4520
# Epoch 198, Loss: 1.0317, Validation Loss: 6.7196
# Epoch 199, Loss: 0.8501, Validation Loss: 6.9354
# Epoch 200, Loss: 0.9393, Validation Loss: 7.6070
# Translate: estoy feliz de su feliz.
# BLEU Score: 0.042422916005101736
